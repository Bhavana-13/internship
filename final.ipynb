# %%
import pandas as pd
import csv
df = pd.read_csv("/content/project.csv")
df.head()
# Out:
#                   Date  Headline  ...       City  Document Tags
# 0  25-Aug-2020 10:33AM       NaN  ...     Sydney            NaN
# 1  25-Aug-2020 10:23AM       NaN  ...  Melbourne            NaN
# 2  25-Aug-2020 10:21AM       NaN  ...        NaN            NaN
# 3  25-Aug-2020 09:11AM       NaN  ...     Sydney            NaN
# 4  25-Aug-2020 09:06AM       NaN  ...     Donald            NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # New Section

# %%
df.drop(['Headline', 'Opening Text','Source','Subregion','Language','Desktop Reach','Mobile Reach','Twitter Social Echo','Facebook Social Echo','Reddit Social Echo','National Viewership','Engagement','Keywords','Tweet Id','Twitter Id','Twitter Client','Document Tags','URL'], axis='columns', inplace=True)

# %%
print(df.shape)
# Out:
# (25, 19)

# %%
df.head()
# Out:
#                   Date  ...       City
# 0  25-Aug-2020 10:33AM  ...     Sydney
# 1  25-Aug-2020 10:23AM  ...  Melbourne
# 2  25-Aug-2020 10:21AM  ...        NaN
# 3  25-Aug-2020 09:11AM  ...     Sydney
# 4  25-Aug-2020 09:06AM  ...     Donald
#
# [5 rows x 19 columns]

# %%
import numpy as np
numpy_array = df.to_numpy()
np.savetxt("text.txt", numpy_array, fmt = "%s")

# %%
json_file = r"""{
  "type": "service_account",
  "project_id": "internship-288205",
  "private_key_id": "c32ea6649b5a09ac281565bfe9f3baeca5de7e22",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nCooRopNjKH4PB0aEskkHDRSy\n-----END PRIVATE KEY-----\n",
  "client_email": "bhavana@internship-288205.iam.gserviceaccount.com",
  "client_id": "109549598845319372658",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/bhavana%40internship-288205.iam.gserviceaccount.com"
}"""
with open('services.json', 'w', encoding="utf-8") as f:
    f.write(json_file)

import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/services.json"

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums


def sample_analyze_entities(text_content):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient()

    
    type_ = enums.Document.Type.PLAIN_TEXT

    
    language = "en"
    document = {"content": text_content, "type": type_, "language": language}

    
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entities(document, encoding_type=encoding_type)

    
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))

        
        print(u"Salience score: {}".format(entity.salience))

        
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))

            
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

  
    print(u"Language of the text: {}".format(response.language))

# %%
import sys
import httplib2
import pandas as pd
import logging
import time
import math
import warnings
import datetime as dt
import os
import re
import string
from datetime import timedelta, date
from urllib.error import HTTPError
from IPython.display import clear_output
import requests
import json

from google.cloud import language
from google.oauth2 import service_account
from google.cloud.language import enums
from google.cloud.language import types

# %%
df['Sentiment'].value_counts().plot.bar()

# %%
def analyze_text_entities(text):
    client = language.LanguageServiceClient()
    document = types.Document(
        content=text,
        type=enums.Document.Type.PLAIN_TEXT)

    response = client.analyze_entities(document=document)

    for entity in response.entities:
        print('=' * 79)
        results = [
            ('name', entity.name),
            ('type', enums.Entity.Type(entity.type).name),
            ('salience', entity.salience),
            ('wikipedia_url', entity.metadata.get('wikipedia_url', '-')),
            ('mid', entity.metadata.get('mid', '-')),
        ]
        for k, v in results:
            print('{:15}: {}'.format(k, v))

sample_analyze_entities(' '.join(list(df.iloc[:,7])))
# Out:
# 'Newborns, toddlers and school age children,flu symptoms,influenza or pneumonia,mild cold Victorian children,good questions,home,morning,piece,remote schooling Initial evidence,children,new studies,outbreaks,plans,school,view,virus Medicine study,adults,aged children,illness,non-teachers,number,possible risk factors,school,severe COVID,workers COVID UNDER CONTROL,children,docs,jobs,local communities,pandemic,parents,responsibility,school,teachers Good information,Runny nose,children,symptoms car crash,government,lower risk,way to school Note to children,tweet,very rare occasions Insecure work,blame for outbreaks,careless toddlers,daycare,media droogies,school children,spread COVID,young workers access,away,challenges,children,group,kids,learning programs,love,money,primary age,proof,purchase,random person,school program,tweet AND hits Insecure work,blame for outbreaks,careless toddlers,daycare,media droogies,school children,spread COVID,young workers Secondary school students,adults to transmit,children,face coverings,guidance,virus LIVES MATTER,children shot,kids in cages,police,school,tens of thousands children,greater risk,road traffic accident,seasonal flu advice,argument,children,govt scientists,health & life,risk,road traffic accident,science,scientifically robust reasons,wheel children,unions,wonder balance of risk,children,good article,lot of data,risk daughters school,home,negative covid test result,policy,symptom then children children,discipline,groups,pandemic,phone,school work,sense of self,teachers Risk of contracting,children,development,health,parents to send,school Fighting Stigma,Health Dept. training nurses,flow chart,school,seat Coronavirus news,Risk of flu,children,deputy CMO,person,road accident Boris Johnson appeals,children,missile hit English schools,children,outbreaks medical officer,overwhelmingly clear evidence,school,virus for children'

# %%
sample_analyze_entities(' '.join(list(df.iloc[:,2])))
# Out:
# Representative name for the entity: @SNHNetwork
# Entity type: OTHER
# Salience score: 0.13032495975494385
# Mention text: @SNHNetwork
# Mention type: PROPER
# Representative name for the entity: @RurbsOz
# Entity type: PERSON
# Salience score: 0.13032495975494385
# Mention text: @RurbsOz
# Mention type: PROPER
# Representative name for the entity: @EdgeLithium
# Entity type: OTHER
# Salience score: 0.13032495975494385
# Mention text: @EdgeLithium
# Mention type: PROPER
# Representative name for the entity: @FerrisGarry
# Entity type: OTHER
# Salience score: 0.05058667063713074
# Mention text: @FerrisGarry
# Mention type: PROPER
# Representative name for the entity: @veeroom
# Entity type: PERSON
# Salience score: 0.05058667063713074
# Mention text: @veeroom
# Mention type: PROPER
# Representative name for the entity: @SarahSoroptimis
# Entity type: OTHER
# Salience score: 0.05058667063713074
# Mention text: @SarahSoroptimis
# Mention type: PROPER
# Representative name for the entity: @rogley8
# Entity type: OTHER
# Salience score: 0.03471165522933006
# Mention text: @rogley8
# Mention type: PROPER
# Representative name for the entity: @markschneider88
# Entity type: OTHER
# Salience score: 0.03471165522933006
# Mention text: @markschneider88
# Mention type: PROPER
# Representative name for the entity: @DarrylMason @Jwashpot
# Entity type: OTHER
# Salience score: 0.03471165522933006
# Mention text: @DarrylMason @Jwashpot
# Mention type: PROPER
# Representative name for the entity: @nativekhan
# Entity type: PERSON
# Salience score: 0.034291449934244156
# Mention text: @nativekhan
# Mention type: PROPER
# Representative name for the entity: @opa1420
# Entity type: OTHER
# Salience score: 0.034291449934244156
# Mention text: @opa1420
# Mention type: PROPER
# Representative name for the entity: @daisyduck2109
# Entity type: OTHER
# Salience score: 0.034291449934244156
# Mention text: @daisyduck2109
# Mention type: PROPER
# Representative name for the entity: @official_porter
# Entity type: PERSON
# Salience score: 0.03187379613518715
# Mention text: @official_porter
# Mention type: PROPER
# Representative name for the entity: @shirleymcbrinn
# Entity type: CONSUMER_GOOD
# Salience score: 0.03187379613518715
# Mention text: @shirleymcbrinn
# Mention type: PROPER
# Representative name for the entity: @bravotvwatchero
# Entity type: PERSON
# Salience score: 0.03187379613518715
# Mention text: @bravotvwatchero
# Mention type: PROPER
# Representative name for the entity: @AngelaKorras
# Entity type: PERSON
# Salience score: 0.02407165616750717
# Mention text: @AngelaKorras
# Mention type: PROPER
# Representative name for the entity: @civicduty1776
# Entity type: OTHER
# Salience score: 0.02407165616750717
# Mention text: @civicduty1776
# Mention type: PROPER
# Representative name for the entity: @pairsonnalitesa
# Entity type: PERSON
# Salience score: 0.02407165616750717
# Mention text: @pairsonnalitesa
# Mention type: PROPER
# Representative name for the entity: @mrssammy23
# Entity type: OTHER
# Salience score: 0.016880692914128304
# Mention text: @mrssammy23
# Mention type: PROPER
# Representative name for the entity: @int2view
# Entity type: OTHER
# Salience score: 0.016880692914128304
# Mention text: @int2view
# Mention type: PROPER
# Representative name for the entity: @alanmcbride
# Entity type: PERSON
# Salience score: 0.016880692914128304
# Mention text: @alanmcbride
# Mention type: PROPER
# Representative name for the entity: @njunjusulupha
# Entity type: PERSON
# Salience score: 0.01059245876967907
# Mention text: @njunjusulupha
# Mention type: PROPER
# Representative name for the entity: @andrewjtagg
# Entity type: PERSON
# Salience score: 0.01059245876967907
# Mention text: @andrewjtagg
# Mention type: PROPER
# Representative name for the entity: @tanyacoleart
# Entity type: OTHER
# Salience score: 0.01059245876967907
# Mention text: @tanyacoleart
# Mention type: PROPER
# Language of the text: en
